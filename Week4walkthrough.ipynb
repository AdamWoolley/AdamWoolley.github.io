# %% [markdown]
# <a href="https://colab.research.google.com/github/AdamWoolley/AdamWoolley.github.io/blob/main/Week4walkthrough.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is just a walkthrough for week 4

# %%
import pandas as pd

# %%
df = pd.read_csv('API_NY.GDP.MKTP.KD.ZG_DS2_en_csv_v2_4666485.csv',skiprows=4)

# %%
df.head(1)
# Out:
#                   Country Name Country Code         Indicator Name  \
# 0                        Aruba          ABW  GDP growth (annual %)
# 1  Africa Eastern and Southern          AFE  GDP growth (annual %)
#
#       Indicator Code  1960      1961      1962      1963      1964      1965  \
# 0  NY.GDP.MKTP.KD.ZG   NaN       NaN       NaN       NaN       NaN       NaN
# 1  NY.GDP.MKTP.KD.ZG   NaN  0.239594  7.980768  5.164334  4.579952  5.327717
#
#    ...      2013      2014      2015      2016      2017      2018      2019  \
# 0  ...  6.429817 -0.020479  3.543630  2.116716  5.482371  1.267218 -2.085600
# 1  ...  4.200209  3.984387  2.952845  2.217017  2.557135  2.485244  2.025941
#
#         2020      2021  Unnamed: 66
# 0 -22.318948       NaN          NaN
# 1  -2.886856  4.303667          NaN
#
# [2 rows x 67 columns]

# %%
df2 = df.drop(['Indicator Name', 'Indicator Code'],axis=1)

# %%
df2
# Out:
#                     Country Name Country Code  1960      1961      1962  \
# 0                          Aruba          ABW   NaN       NaN       NaN
# 1    Africa Eastern and Southern          AFE   NaN  0.239594  7.980768
# 2                    Afghanistan          AFG   NaN       NaN       NaN
# 3     Africa Western and Central          AFW   NaN  1.848752  3.770220
# 4                         Angola          AGO   NaN       NaN       NaN
# ..                           ...          ...   ...       ...       ...
# 261                       Kosovo          XKX   NaN       NaN       NaN
# 262                  Yemen, Rep.          YEM   NaN       NaN       NaN
# 263                 South Africa          ZAF   NaN  3.844734  6.177931
# 264                       Zambia          ZMB   NaN  1.361382 -2.490839
# 265                     Zimbabwe          ZWE   NaN  6.316157  1.434471
#
#          1963       1964       1965      1966      1967  ...      2013  \
# ...

# %%
df3 = df2.set_index(['Country Name','Country Code']).stack().reset_index()

# %%
df4 = df3.rename(columns={'level_2':'Year',0:'GDP growth (annual %)'})

# %%
df4.set_index('Country Code').to_csv('mycsv.csv')

# %%
df3.set_index(['Country Name', 'Country Code','level_2']).unstack()
# Out:
#                                                   0                        \
# level_2                                        1961       1962       1963
# Country Name                Country Code
# Afghanistan                 AFG                 NaN        NaN        NaN
# Africa Eastern and Southern AFE            0.239594   7.980768   5.164334
# Africa Western and Central  AFW            1.848752   3.770220   7.272440
# Albania                     ALB                 NaN        NaN        NaN
# Algeria                     DZA          -13.605441 -19.685042  34.313729
# ...                                             ...        ...        ...
# West Bank and Gaza          PSE                 NaN        NaN        NaN
# World                       WLD            3.790542   5.316458   5.184865
# Yemen, Rep.                 YEM                 NaN        NaN        NaN
# Zambia                      ZMB            1.361382  -2.490839   3.272393
# ...

# %% [markdown]
# This is how to do the scrapping for

# %% [markdown]
# ###https://ratings.fide.com/top_lists.phtml

# %%
table_list=pd.read_html('chess_table.html')

# %%
len(table_list)
# Out:
# 1

# %%
table_list[0] = table_list[0]['Avg12M'].str.split(' ').str[0].astype(float)

# %%
s='2862 (1)'

# %%
int(s.split(' ')[0])
# Out:
# 2862

# %%
table_list[0] = chess_df

# %%
chess_df['Rating last year'] = chess_df['Avg12M'].str.split(' ').str[0].astype(float)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-526dddc3160a> in <module>
# ----> 1 chess_df['Rating last year'] = chess_df['Avg12M'].str.split(' ').str[0].astype(float)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
# ...

# %% [markdown]
# # New Section

# %%
import requests, pandas as pd

# %%
tables=pd.read_html('https://www.indexmundi.com/facts/indicators/SI.POV.GINI/rankings/africa')

# %%
df=tables[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-1479a1117005> in <module>
# ----> 1 df=tables[1]
#
# IndexError: list index out of range
